# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

from tensorflow import keras

(X_train_full, y_train_full), (X_test, y_test) = keras.datasets.fashion_mnist.load_data()

X_train_full = X_train_full.astype(np.float32) / 255
X_test = X_test.astype(np.float32) / 255

X_train, X_valid = X_train_full[:-5000], X_train_full[-5000:]
y_train, y_valid = y_train_full[:-5000], y_train_full[-5000:]

# %%
def rounded_accuracy(y_true, y_pred):
    return keras.metrics.binary_accuracy(tf.round(y_true), tf.round(y_pred))

# %%
tf.random.set_seed(42)
np.random.seed(42)

stacked_encoder = keras.models.Sequential([
    keras.layers.Flatten(input_shape=[28, 28]),
    keras.layers.Dense(100, activation="selu"),
    
    # 각 입력 이미지에 대해 인코더는 크기가 30인 벡터 출력
    keras.layers.Dense(30, activation="selu"),
])

stacked_decoder = keras.models.Sequential([
    # 인코더가 출력한 크기가 30인 코딩을 받게 됨
    keras.layers.Dense(100, activation="selu", input_shape=[30]),
    keras.layers.Dense(28 * 28, activation="sigmoid"),
    keras.layers.Reshape([28, 28])
])

stacked_ae = keras.models.Sequential([stacked_encoder, stacked_decoder])

stacked_ae.compile(loss="binary_crossentropy",
                   optimizer=keras.optimizers.SGD(lr=1.5), metrics=[rounded_accuracy])

history = stacked_ae.fit(X_train, X_train, epochs=20,
                         validation_data=(X_valid, X_valid))
# Out:
# Epoch 1/20
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.3381 - rounded_accuracy: 0.8870 - val_loss: 0.3173 - val_rounded_accuracy: 0.8989
# Epoch 2/20
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.3056 - rounded_accuracy: 0.9151 - val_loss: 0.3020 - val_rounded_accuracy: 0.9199
# Epoch 3/20
# 1719/1719 [==============================] - 11s 7ms/step - loss: 0.2986 - rounded_accuracy: 0.9215 - val_loss: 0.2986 - val_rounded_accuracy: 0.9198
# Epoch 4/20
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.2948 - rounded_accuracy: 0.9249 - val_loss: 0.2938 - val_rounded_accuracy: 0.9285
# Epoch 5/20
# 1719/1719 [==============================] - 9s 6ms/step - loss: 0.2923 - rounded_accuracy: 0.9272 - val_loss: 0.2920 - val_rounded_accuracy: 0.9284
# Epoch 6/20
# 1719/1719 [==============================] - 10s 6ms/step - loss: 0.2904 - rounded_accuracy: 0.9289 - val_loss: 0.2914 - val_rounded_accuracy: 0.9305
# Epoch 7/20
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.2890 - rounded_accuracy: 0.9301 - val_loss: 0.2905 - val_rounded_accuracy: 0.9283
# Epoch 8/20
# 1719/1719 [==============================] - 10s 6ms/step - loss: 0.2877 - rounded_accuracy: 0.9313 - val_loss: 0.2972 - val_rounded_accuracy: 0.9274
# Epoch 9/20
# 1719/1719 [==============================] - 10s 6ms/step - loss: 0.2869 - rounded_accuracy: 0.9321 - val_loss: 0.2906 - val_rounded_accuracy: 0.9258
# Epoch 10/20
# 1719/1719 [==============================] - 10s 6ms/step - loss: 0.2859 - rounded_accuracy: 0.9330 - val_loss: 0.2879 - val_rounded_accuracy: 0.9307
# Epoch 11/20
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.2851 - rounded_accuracy: 0.9337 - val_loss: 0.2865 - val_rounded_accuracy: 0.9348
# Epoch 12/20
# 1719/1719 [==============================] - 6s 4ms/step - loss: 0.2845 - rounded_accuracy: 0.9341 - val_loss: 0.2854 - val_rounded_accuracy: 0.9357
# Epoch 13/20
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.2839 - rounded_accuracy: 0.9346 - val_loss: 0.2846 - val_rounded_accuracy: 0.9350
# Epoch 14/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.2835 - rounded_accuracy: 0.9350 - val_loss: 0.2843 - val_rounded_accuracy: 0.9365
# Epoch 15/20
# 1719/1719 [==============================] - 8s 4ms/step - loss: 0.2830 - rounded_accuracy: 0.9355 - val_loss: 0.2841 - val_rounded_accuracy: 0.9351
# Epoch 16/20
# 1719/1719 [==============================] - 8s 4ms/step - loss: 0.2825 - rounded_accuracy: 0.9359 - val_loss: 0.2847 - val_rounded_accuracy: 0.9354
# Epoch 17/20
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.2822 - rounded_accuracy: 0.9360 - val_loss: 0.2836 - val_rounded_accuracy: 0.9362
# Epoch 18/20
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.2819 - rounded_accuracy: 0.9363 - val_loss: 0.2831 - val_rounded_accuracy: 0.9362
# Epoch 19/20
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.2816 - rounded_accuracy: 0.9366 - val_loss: 0.2826 - val_rounded_accuracy: 0.9375
# Epoch 20/20
# 1719/1719 [==============================] - 11s 6ms/step - loss: 0.2812 - rounded_accuracy: 0.9368 - val_loss: 0.2838 - val_rounded_accuracy: 0.9369

# %%
def plot_image(image):
    plt.imshow(image, cmap="binary")
    plt.axis("off")

# %%
def show_reconstructions(model, images=X_valid, n_images=5):
    reconstructions = model.predict(images[:n_images])
    fig = plt.figure(figsize=(n_images * 1.5, 3))
    
    for image_index in range(n_images):
        plt.subplot(2, n_images, 1 + image_index)
        plot_image(images[image_index])
        plt.subplot(2, n_images, 1 + n_images + image_index)
        plot_image(reconstructions[image_index])

# %%
show_reconstructions(stacked_ae)
